# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('Food_Delivery_Times.csv')

# %%
df[df.isnull().any(axis=1)]
# Out:
#      Order_ID  Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 6         627         9.52   Clear           Low         NaN         Bike
# 14        939         2.80   Clear          High     Morning      Scooter
# 24        211        11.20   Clear        Medium     Morning         Bike
# 42        313         0.99     NaN        Medium     Evening         Bike
# 71        494         4.17     NaN           Low     Evening      Scooter
# ..        ...          ...     ...           ...         ...          ...
# 974       414        11.68   Clear           NaN   Afternoon      Scooter
# 976       344         8.96   Snowy           NaN     Morning          Car
# 987       331         7.44   Rainy           Low     Evening         Bike
# 988       215        14.39   Rainy        Medium     Morning      Scooter
# 989       467         6.07     NaN           Low   Afternoon         Bike
#
#      Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Order_ID                1000 non-null   int64
#  1   Distance_km             1000 non-null   float64
#  2   Weather                 970 non-null    object
#  3   Traffic_Level           970 non-null    object
#  4   Time_of_Day             970 non-null    object
#  5   Vehicle_Type            1000 non-null   object
#  6   Preparation_Time_min    1000 non-null   int64
#  7   Courier_Experience_yrs  970 non-null    float64
#  8   Delivery_Time_min       1000 non-null   int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 70.4+ KB

# %%
df.describe(include ='all')
# Out:
#            Order_ID  Distance_km Weather Traffic_Level Time_of_Day  \
# count   1000.000000  1000.000000     970           970         970
# unique          NaN          NaN       5             3           4
# top             NaN          NaN   Clear        Medium     Morning
# freq            NaN          NaN     470           390         308
# mean     500.500000    10.059970     NaN           NaN         NaN
# std      288.819436     5.696656     NaN           NaN         NaN
# min        1.000000     0.590000     NaN           NaN         NaN
# 25%      250.750000     5.105000     NaN           NaN         NaN
# 50%      500.500000    10.190000     NaN           NaN         NaN
# 75%      750.250000    15.017500     NaN           NaN         NaN
# max     1000.000000    19.990000     NaN           NaN         NaN
#
#        Vehicle_Type  Preparation_Time_min  Courier_Experience_yrs  \
# count          1000           1000.000000              970.000000
# ...

# %%
df['Traffic_Level'].nunique()
# Out:
# 3

# %%
df.groupby('Traffic_Level').count()
# Out:
#                Order_ID  Distance_km  Weather  Time_of_Day  Vehicle_Type  \
# Traffic_Level
# High                197          197      191          193           197
# Low                 383          383      374          367           383
# Medium              390          390      375          381           390
#
#                Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# Traffic_Level
# High                            197                     191                197
# Low                             383                     371                383
# Medium                          390                     378                390

# %%
df.isnull().sum()
# Out:
# Order_ID                   0
# Distance_km                0
# Weather                   30
# Traffic_Level             30
# Time_of_Day               30
# Vehicle_Type               0
# Preparation_Time_min       0
# Courier_Experience_yrs    30
# Delivery_Time_min          0
# dtype: int64

# %%
df.nunique()
# Out:
# Order_ID                  1000
# Distance_km                785
# Weather                      5
# Traffic_Level                3
# Time_of_Day                  4
# Vehicle_Type                 3
# Preparation_Time_min        25
# Courier_Experience_yrs      10
# Delivery_Time_min          108
# dtype: int64

# %%
df['Courier_Experience_yrs'].value_counts(ascending=False)
# Out:
# Courier_Experience_yrs
# 6.0    109
# 9.0    108
# 1.0    107
# 8.0    101
# 2.0     99
# 4.0     94
# 7.0     91
# 0.0     91
# 5.0     90
# 3.0     80
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Order_ID', 'Distance_km', 'Weather', 'Traffic_Level', 'Time_of_Day',
#        'Vehicle_Type', 'Preparation_Time_min', 'Courier_Experience_yrs',
#        'Delivery_Time_min'],
#       dtype='object')

# %%
category = [ 'Weather', 'Traffic_Level', 'Time_of_Day',
       'Vehicle_Type', 'Preparation_Time_min', 'Courier_Experience_yrs']

for column in category:
    print(df[column].value_counts(ascending=False))
# Out:
# Weather
# Clear    470
# Rainy    204
# Foggy    103
# Snowy     97
# Windy     96
# Name: count, dtype: int64
# Traffic_Level
# Medium    390
# Low       383
# High      197
# Name: count, dtype: int64
# Time_of_Day
# Morning      308
# Evening      293
# Afternoon    284
# Night         85
# Name: count, dtype: int64
# Vehicle_Type
# Bike       503
# Scooter    302
# Car        195
# Name: count, dtype: int64
# Preparation_Time_min
# 14    52
# 16    49
# 25    48
# 10    47
# 9     46
# 11    46
# 17    45
# 6     44
# 22    42
# 8     42
# 27    40
# 28    40
# 26    40
# 29    39
# 21    39
# 20    39
# 12    38
# 23    38
# 7     37
# 24    37
# 19    35
# 13    30
# 5     30
# 15    29
# 18    28
# Name: count, dtype: int64
# Courier_Experience_yrs
# 6.0    109
# 9.0    108
# 1.0    107
# 8.0    101
# 2.0     99
# 4.0     94
# 7.0     91
# 0.0     91
# 5.0     90
# 3.0     80
# Name: count, dtype: int64

# %%
df.head(5)
# Out:
#    Order_ID  Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0       522         7.93   Windy           Low   Afternoon      Scooter
# 1       738        16.42   Clear        Medium     Evening         Bike
# 2       741         9.52   Foggy           Low       Night      Scooter
# 3       661         7.44   Rainy        Medium   Afternoon      Scooter
# 4       412        19.03   Clear           Low     Morning         Bike
#
#    Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 0                    12                     1.0                 43
# 1                    20                     2.0                 84
# 2                    28                     1.0                 59
# 3                     5                     1.0                 37
# 4                    16                     5.0                 68

# %%
fig = px.histogram(df, x= 'Distance_km', nbins=100,color_discrete_sequence=['black'])
fig2 = px.box(df, x= 'Distance_km',color_discrete_sequence=['black'])
fig.show()
fig2.show()
# Out:
# <div>                            <div id="6e381aa1-324f-407d-8ccd-0fd585d39035" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6e381aa1-324f-407d-8ccd-0fd585d39035")) {                    Plotly.newPlot(                        "6e381aa1-324f-407d-8ccd-0fd585d39035",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Distance_km=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"black","pattern":{"shape":""}},"name":"","nbinsx":100,"offsetgroup":"","orientation":"v","showlegend":false,"x":[7.93,16.42,9.52,7.44,19.03,19.4,9.52,17.39,1.78,10.62,16.86,15.54,10.89,4.69,2.8,2.17,17.86,2.53,6.58,5.38,15.56,13.08,0.86,5.83,11.2,14.59,12.91,13.92,4.04,18.05,12.88,19.45,4.58,19.73,2.47,17.8,5.96,12.85,1.02,6.
# ...

# %%
fig3 = px.scatter(df , x= 'Preparation_Time_min', y = 'Delivery_Time_min'
                 ,color_discrete_sequence=['black'],trendline='ols',
                 trendline_color_override='red',template='simple_white')
fig3.show()
# Out:
# <div>                            <div id="b3f0647c-95ed-4d7e-9ac0-bcf93fcc0873" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3f0647c-95ed-4d7e-9ac0-bcf93fcc0873")) {                    Plotly.newPlot(                        "b3f0647c-95ed-4d7e-9ac0-bcf93fcc0873",                        [{"hovertemplate":"Preparation_Time_min=%{x}<br>Delivery_Time_min=%{y}<extra></extra>","legendgroup":"","marker":{"color":"black","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[12,20,28,5,16,8,12,5,20,29,13,29,12,12,10,15,5,6,6,26,28,16,26,27,23,15,11,18,11,10,8,20,22,27,27,16,22,18,25,14,8,25,15,5,15,16,14,19,23,21,8,25,20,8,10,10,26,20,16,11,17,11,21,17,26,16,29,13,14,27,5,5,16,16,6,9,20,14,23,13,11,23,29,6,23,23,26,14,21
# ...

# %%
fig = px.box(df ,x= 'Preparation_Time_min', y = 'Delivery_Time_min',color_discrete_sequence=['black']
            ,width =1200,template='simple_white')
fig.show()
# Out:
# <div>                            <div id="f7c3a070-7687-40c0-89a1-9d0a439b6c8f" class="plotly-graph-div" style="height:525px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7c3a070-7687-40c0-89a1-9d0a439b6c8f")) {                    Plotly.newPlot(                        "f7c3a070-7687-40c0-89a1-9d0a439b6c8f",                        [{"alignmentgroup":"True","hovertemplate":"Preparation_Time_min=%{x}<br>Delivery_Time_min=%{y}<extra></extra>","legendgroup":"","marker":{"color":"black"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":[12,20,28,5,16,8,12,5,20,29,13,29,12,12,10,15,5,6,6,26,28,16,26,27,23,15,11,18,11,10,8,20,22,27,27,16,22,18,25,14,8,25,15,5,15,16,14,19,23,21,8,25,20,8,10,10,26,20,16,11,17,11,21,17,26,16,29,13,14,27,5,5,16,16,6,9,20,14,23,13,1
# ...

# %%
df.head(1)
# Out:
#    Order_ID  Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0       522         7.93   Windy           Low   Afternoon      Scooter
#
#    Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# 0                    12                     1.0                 43

# %%
fig = px.histogram(df, x= 'Preparation_Time_min', nbins=25)
fig2 = px.box(df, x= 'Preparation_Time_min',color_discrete_sequence=['black'])
fig.show()
fig2.show()
# Out:
# <div>                            <div id="01d43005-b1cc-437a-978d-ea5071e77c29" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01d43005-b1cc-437a-978d-ea5071e77c29")) {                    Plotly.newPlot(                        "01d43005-b1cc-437a-978d-ea5071e77c29",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Preparation_Time_min=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":25,"offsetgroup":"","orientation":"v","showlegend":false,"x":[12,20,28,5,16,8,12,5,20,29,13,29,12,12,10,15,5,6,6,26,28,16,26,27,23,15,11,18,11,10,8,20,22,27,27,16,22,18,25,14,8,25,15,5,15,16,14,19,23,21,8,25,20,8,10,10,26,20,16,11,17,11,21,17,26,16,29,13,14,27,5,5,1
# ...

# %%
df['Preparation_Time_min'].value_counts(ascending=False)
# Out:
# Preparation_Time_min
# 14    52
# 16    49
# 25    48
# 10    47
# 9     46
# 11    46
# 17    45
# 6     44
# 22    42
# 8     42
# 27    40
# 28    40
# 26    40
# 29    39
# 21    39
# 20    39
# 12    38
# 23    38
# 7     37
# 24    37
# 19    35
# 13    30
# 5     30
# 15    29
# 18    28
# Name: count, dtype: int64

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Distance_km, Weather, Traffic_Level, Time_of_Day, Vehicle_Type, Preparation_Time_min, Courier_Experience_yrs, Delivery_Time_min]
# Index: []

# %%
df
# Out:
#      Order_ID  Distance_km Weather Traffic_Level Time_of_Day Vehicle_Type  \
# 0         522         7.93   Windy           Low   Afternoon      Scooter
# 1         738        16.42   Clear        Medium     Evening         Bike
# 2         741         9.52   Foggy           Low       Night      Scooter
# 3         661         7.44   Rainy        Medium   Afternoon      Scooter
# 4         412        19.03   Clear           Low     Morning         Bike
# ..        ...          ...     ...           ...         ...          ...
# 995       107         8.50   Clear          High     Evening          Car
# 996       271        16.28   Rainy           Low     Morning      Scooter
# 997       861        15.62   Snowy          High     Evening      Scooter
# 998       436        14.17   Clear           Low   Afternoon         Bike
# 999       103         6.63   Foggy           Low       Night      Scooter
#
#      Preparation_Time_min  Courier_Experience_yrs  Delivery_Time_min
# ...

# %%
df['Delivery_Time_min'].describe()
# Out:
# count    1000.000000
# mean       56.732000
# std        22.070915
# min         8.000000
# 25%        41.000000
# 50%        55.500000
# 75%        71.000000
# max       153.000000
# Name: Delivery_Time_min, dtype: float64

# %%
fig2 = px.histogram(df, x= 'Delivery_Time_min',
                    color_discrete_sequence=['black'],
                   marginal='box',height=300)
fig2.show()
# Out:
# <div>                            <div id="39481d9e-c654-427d-bac5-f0e7eb78c7cd" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("39481d9e-c654-427d-bac5-f0e7eb78c7cd")) {                    Plotly.newPlot(                        "39481d9e-c654-427d-bac5-f0e7eb78c7cd",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Delivery_Time_min=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"black","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[43,84,59,37,68,57,49,46,35,73,88,76,53,36,33,35,50,24,27,47,72,58,37,56,73,64,56,70,70,123,52,108,45,111,44,73,45,61,34,47,52,67,32,8,36,67,43,36,36,56,56,47,104,50,31,35,44,23,61,82,69,69,60,40,38,52,68,31,54,87,62,22,42
# ...
